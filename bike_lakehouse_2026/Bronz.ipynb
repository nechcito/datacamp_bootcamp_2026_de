# %% [markdown]
# # Read from csv. and Write to bronze layer

# %% [markdown]
# ##Load Cust_info.csv

# %%
df=spark.read.csv("/Volumes/workspace/bronze/source_systems/source_crm/cust_info.csv",header=True,inferSchema=True)
df.write.mode("overwrite").saveAsTable("bronze.crm_cust_info")

# %% [markdown]
# ##Load Prd_info.csv

# %%
df=spark.read.csv("/Volumes/workspace/bronze/source_systems/source_crm/prd_info.csv",header=True,inferSchema=True)
df.write.mode("overwrite").saveAsTable("bronze.crm_prd_info")

# %% [markdown]
# ##Load Sales_deatils_info.csv

# %%
df=spark.read.csv("/Volumes/workspace/bronze/source_systems/source_crm/sales_details.csv",header=True,inferSchema=True)
df.write.mode("overwrite").saveAsTable("bronze.crm_sales_details")

# %% [markdown]
# ##Load Cust_az12.csv

# %%
df=spark.read.csv("/Volumes/workspace/bronze/source_systems/source_erp/CUST_AZ12.csv",header=True,inferSchema=True)
df.write.mode("overwrite").saveAsTable("bronze.erp_cust_AZ12")

# %% [markdown]
# ##Load Loc_a101.csv

# %%
df=spark.read.csv("/Volumes/workspace/bronze/source_systems/source_erp/LOC_A101.csv",header=True,inferSchema=True)
df.write.mode("overwrite").saveAsTable("bronze.erp_loc_A101")

# %% [markdown]
# ##Load PX_cat_g1v2.csv

# %%
df=spark.read.csv("/Volumes/workspace/bronze/source_systems/source_erp/PX_CAT_G1V2.csv",header=True,inferSchema=True)
df.write.mode("overwrite").saveAsTable("bronze.erp_px_cat_G1V2")
